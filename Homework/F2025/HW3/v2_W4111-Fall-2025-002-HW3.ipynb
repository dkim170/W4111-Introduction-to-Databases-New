# %% [markdown]
# # W4111-Fall-2025-002-HW2

# %% [markdown]
# ## Instructions

# %% [markdown]
# - The homework is due on 12-November at 11:59 PM.
# - We will create a Gradescope location/entry for submitting the homework. You will need to tag the pages in the submission to match pages to questions.
# - The submission format will be a PDF version on this notebook.
# - Please use the [Ed discussion](https://edstem.org/us/courses/83997/discussion/7247207) to ask questions. Please monitor the thread for clarifications and updates.

# %% [markdown]
# ## Setup

# %%
# %load_ext sql

# %%
# Replace the password in this URL to match your local MySQL password.
#
db_url = "mysql+pymysql://root:dbuserdbuser@localhost"

# %%
# %sql $db_url

# %%
# This is a hack to fix a version problem/incompatibility  with some of the packages and magics.
#
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %% [markdown]
# ## Written Questions

# %% [markdown]
# ### W1

# %% [markdown]
# #### Question

# %% [markdown]
# The following are two of Codd's rules:
#
# __Rule 1: The information rule:__ All information in a relational data base is represented explicitly at the logical level and in exactly one way – by values in tables.
#
# __Rule 4: Dynamic online catalog based on the relational model:__ The data base description is represented at the logical level in the same way as ordinary data, so that authorized users can apply the same relational language to its interrogation as they apply to the regular data.
#
# Briefly explain the rules and their relationship. What are some types of information in the _dynamic online catalog._

# %% [markdown]
# #### Answer

# %% [markdown]
# ### W2

# %% [markdown]
# #### Question

# %% [markdown]
# Briefly explain _First Normal Form._

# %% [markdown]
# #### Answer

# %% [markdown]
# ### W3

# %% [markdown]
# #### Question

# %% [markdown]
# Briefly explain and indicate the differences between _natural join, equi-join_ and _theta join._

# %% [markdown]
# #### Answer

# %% [markdown]
# ### W4

# %% [markdown]
# #### Question

# %% [markdown]
# A common data engineering task is loading a comma separate value (CSV) file into a database table. Briefly explain the concept of _schema cleanup_ when loading the data.

# %% [markdown]
# #### Answer

# %% [markdown]
# ### W5

# %% [markdown]
# #### Question

# %% [markdown]
# Briefly explain the concept of and the benefits of creating _indexes_ on relational tables. What is a negative to creating too many, unneccessary indexes.

# %% [markdown]
# #### Answer

# %% [markdown]
# ### W6

# %% [markdown]
# #### Question

# %% [markdown]
# Briefly explain the simularities and differences between _functions, procedures_ and _triggers._

# %% [markdown]
# #### Answer

# %% [markdown]
# ### W7

# %% [markdown]
# #### Question

# %% [markdown]
# Briefly explain the concepts of and relationship between _user_ and _role._ What is the motivation for creating a _role._

# %% [markdown]
# #### Answer

# %% [markdown]
# ### W8

# %% [markdown]
# #### Question

# %% [markdown]
# Briefly explain the concepts of _connection, session_ and _cursor._

# %% [markdown]
# #### Answer

# %% [markdown]
# ### W9

# %% [markdown]
# #### Question

# %% [markdown]
# Consider the scenario of implementing funds transfer between two accounts using SQL. What database concept would you use to ensure correct transfers in the face of failures?

# %% [markdown]
# #### Answer

# %% [markdown]
# ### W10

# %% [markdown]
# #### Question

# %% [markdown]
# Briefly explain the concept of _the perils of redundancy._

# %% [markdown]
# #### Answer

# %% [markdown]
# ### W11

# %% [markdown]
# #### Question

# %% [markdown]
# Briefly explain the concept of _lossy decomposition._

# %% [markdown]
# #### Answer

# %% [markdown]
# ### W12

# %% [markdown]
# #### Question

# %% [markdown]
# | <img src="./fds.jpg" width="700px"> |
# | :---: |
# | __Sample Data__ |
#
# Find the functional dependencies in the sample data. Express a functional dependenc in the form <br>
# $(columnName1, columnName2, ...) \rightarrow \ $(columnNamej, columnNamek, ...)$.

# %% [markdown]
# #### Answer

# %% [markdown]
# ### W13

# %% [markdown]
# #### Question

# %% [markdown]
# Very briefly explain the normalization concepts of and differences between _BCNF_ and _3NF._

# %% [markdown]
# #### Answer

# %% [markdown]
# ### W14

# %% [markdown]
# #### Question

# %% [markdown]
# Briefly explain the goals of normalization.

# %% [markdown]
# #### Answer

# %% [markdown]
# ### W15

# %% [markdown]
# #### Question

# %% [markdown]
# Briefly explain the motivations for/benefits of NoSQL databases relative to relational databases.

# %% [markdown]
# #### Answer

# %% [markdown]
# ## Data Modeling

# %% [markdown]
# ### ER1

# %% [markdown]
# #### Question

# %% [markdown]
# Consider the following scenario:
# There are three logical entity sets:
# 1. ```Person``` with attributes:
#    1. ```lastName```
#    2. ```firstName```
#    3. ```email```
# 2. ```Faculty``` __is a__ ```Person``` and adds the following attributes:
#    1. ```title```
#    2. ```salary```
# 3. ```Student``` __is a__ ```Person``` and adds the following attributes.
#    1. ```graduation_year```
#    2. ```major```
# 4. ```contact_phone```
#    1. ```country_code```
#    2. ```phone_number```
#    3. ```extensions```
#
# The specialization of ```Person``` into ```Faculty``` and ```Student``` is _overlapping_ and _incomplete._
#
# A ```Person``` may be associated with 0, 1 or many ```contact_phones.``` There are the following requirements:
# 1. Each association has a type of the form ```primary```, ```secondary.```
# 2. A ```Person``` can have only one ```primary``` ```contact_phone```.
# 3. A ```Person``` can have only one ```secondary``` ```contact_phone```.
#
# Draw a logical _entity relationship_ diagram representing the requirements using the notation we have used in class. You must use Lucidchart or an equivalent tool. Please add notes to your diagram expressing any assumptions or additional information you want to convey.

# %% [markdown]
# #### Answer

# %% [markdown]
# ## Relational Algebra

# %% [markdown]
# ### R1

# %% [markdown]
# #### Question

# %% [markdown]
# Consider the following sample data
#
# | <img src="./r1.jpg" width="400px"> |
# | :---: |
# | __Sample Data__ |

# %% [markdown]
# Write a _relational algebra_ statement using a single operator that produces the following relation. Also include a screen capture of the statement's execution in the [Relax](https://dbis-uibk.github.io/relax/calc/local/uibk/local/0) relational calculator.
#
# | <img src="./r2.jpg" width="200px"> |
# | :---: |
# | __Result Data__ |

# %% [markdown]
# #### Answer

# %% [markdown]
# ### R2

# %% [markdown]
# #### Question

# %% [markdown]
# Briefly explain a _semi-join_ and how it differs from a _join._

# %% [markdown]
# __Answer__

# %% [markdown]
# ## SQL
#
# You will use _classic models_ for the SQL questions. You should already have used _classic models_ and have it loaded. If you have not done so, please load the data into MySQL.

# %% [markdown]
# ### S1

# %% [markdown]
# #### Question

# %% [markdown]
# Without using a ```JOIN``` produce a table that matches the following result, which is basic information about ```customers``` who have not placed any orders.
#
# | <img src="./s1.jpg" width=700px;> |
# | :---: |
# | __Customers without Orders__ |

# %% [markdown]
# #### Answer

# %%
# %%sql

# %% [markdown]
# ### S2

# %% [markdown]
# #### Question

# %% [markdown]
# Use ```orderdetails``` and ```products``` for this problem.
#
# The revenue associated with an ```orderdetails``` is ```quantityordered*priceeach```.
#
# Write an SQL statement that computes the following table where
# 1. ```productCode``` and ```productName``` come from ```products```.
# 2. ```total_ordered``` is the total ordered over all ```orderdetails```.
# 3. ```totalrevenye``` is the total revenue over all ```orderdetails```.
# 4. ```no_of_orders``` is the number of ```orders``` containing an ```orderdetails``` for the product.

# %% [markdown]
# | <img src="s2.jpg" width=1100px;> |
# | :---: |
# | __Faculty and Sections__ |
#
# The table list information about instructors, the sections they teach and the credits for the section. There is a row for an instructor even if they do not teach any sections.
#
# You must use _exactly one_ ```JOIN``` and __exactly one__ subquery.

# %% [markdown]
# #### Answer

# %%
# %%sql
